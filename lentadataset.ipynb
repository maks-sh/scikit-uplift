# %% [markdown]
# # Lenta dataset
# [Link](https://winterschool123.s3.eu-north-1.amazonaws.com/lentadataset.csv.gz)

# %%
import urllib.request
import pandas as pd

# %%
gz_path = 'lentadataset.csv.gz'
url = 'https://winterschool123.s3.eu-north-1.amazonaws.com/lentadataset.csv.gz'
file = urllib.request.urlretrieve(url, gz_path)

# %%
data = pd.read_csv("lentadataset.csv.gz")
